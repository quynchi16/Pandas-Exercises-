# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/titanic_train.csv)

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic = pd.read_csv('https://raw.githubusercontent.com/thieu1995/csv-files/main/data/pandas/titanic_train.csv')

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic = titanic.set_index('PassengerId')

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
gender_counts = titanic['Sex'].value_counts()
gender_counts.plot.pie(autopct='%1.1f%%', startangle=90, colors=['skyblue', 'pink'], figsize=(6, 6))
plt.title('Male/Female Proportion on Titanic')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
plt.figure(figsize=(10, 6))
plt.scatter(titanic[titanic['Sex'] == 'male']['Age'], titanic[titanic['Sex'] == 'male']['Fare'], color='skyblue', label='Male', alpha=0.7)
plt.scatter(titanic[titanic['Sex'] == 'female']['Age'], titanic[titanic['Sex'] == 'female']['Fare'], color='pink', label='Female', alpha=0.7)
plt.xlabel('Age')
plt.ylabel('Fare')
plt.title('Fare Paid vs. Age (by Gender)')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Step 7. How many people survived?

# %%
survived_count = titanic['Survived'].sum()
print(f"Number of people who survived: {survived_count}")
# Out:
# Number of people who survived: 342

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
plt.figure(figsize=(10, 6))
plt.hist(titanic['Fare'], bins=30, color='lightgreen', edgecolor='black')
plt.xlabel('Fare')
plt.ylabel('Frequency')
plt.title('Distribution of Fare Paid')
plt.grid(axis='y', alpha=0.75)
plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.
